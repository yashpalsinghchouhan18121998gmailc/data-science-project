# %%
import sys
# !{sys.executable} -m pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import sys

# %%
from matplotlib import style
style.use('ggplot')
# %matplotlib inline

# %%
import plotly
import plotly.express as px

# %%
import plotly.graph_objects as go
plt.rcParams['figure.figsize']=17,12

# %%
import cufflinks as cf
import plotly.offline as pyo
from plotly.offline import init_notebook_mode,plot,iplot

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9e8b2c60-a570-498c-a195-5ba0939da2bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e8b2c60-a570-498c-a195-5ba0939da2bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid project data 18-06-2020.csv to covid project data 18-06-2020.csv

# %%
for fn in uploaded.keys():
  print('user uploaded file"{name}" with length{length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
# user uploaded file"covid project data 18-06-2020.csv" with length1188 bytes

# %%
uploaded
# Out:
# {'covid project data 18-06-2020.csv': b'S. No.,Name of State / UT,Active Cases,Cured,Deaths,Total Confirmed cases\r\n1,Andaman and Nicobar Islands,11,33,0,44\r\n2,Andhra Pradesh,3340,3641,90,7071\r\n3,Arunachal Pradesh,92,7,0,99\r\n4,Assam,1955,2642,8,4605\r\n5,Bihar,1972,4926,44,6942\r\n6,Chandigarh,59,303,6,368\r\n7,Chhattisgarh,674,1180,10,1864\r\n8,Dadra and Nagar Haveli and Daman and Diu,45,12,0,57\r\n9,Delhi,27741,17457,1904,47102\r\n10,Goa,560,96,0,656\r\n11,Gujarat,6103,17430,1560,25093\r\n12,Haryana,4750,3952,130,8832\r\n13,Himachal Pradesh,189,372,8,569\r\n14,Jammu and Kashmir,2427,2914,65,5406\r\n15,Jharkhand,734,1151,10,1895\r\n16,Karnataka,2828,4804,102,7734\r\n17,Kerala,1351,1326,20,2697\r\n18,Ladakh,594,92,1,687\r\n19,Madhya Pradesh,2374,8388,482,11244\r\n20,Maharashtra,51935,59166,5651,116752\r\n21,Manipur,360,192,0,552\r\n22,Meghalaya,13,30,1,44\r\n23,Mizoram,120,1,0,121\r\n24,Nagaland,90,103,0,193\r\n25,Odisha,1280,3047,11,4338\r\n26,Puducherry,129,109,7,245\r\n27,P
# ...

# %%
import io

# %%
sample_df = pd.read_csv(io.StringIO(uploaded['covid project data 18-06-2020.csv'].decode('utf-8')))
sample_df.head()
# Out:
#    S. No.           Name of State / UT  ...  Deaths  Total Confirmed cases
# 0       1  Andaman and Nicobar Islands  ...       0                     44
# 1       2               Andhra Pradesh  ...      90                   7071
# 2       3            Arunachal Pradesh  ...       0                     99
# 3       4                        Assam  ...       8                   4605
# 4       5                        Bihar  ...      44                   6942
#
# [5 rows x 6 columns]

# %%
## total recorded with respect to indian-states

# %%
plt.plot(sample_df['Total Confirmed cases'],sample_df['Name of State / UT'])

# %%
## deaths due to covid-19 with respect to states

# %%
plt.plot(sample_df['Deaths'],sample_df['Name of State / UT'])

# %%
## here we can see that where we find the total confirmed cases more the same states have more death rate

# %%
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
## here the bar graph showing the most no. of active cases in states of india

# %%
sns.barplot(x=sample_df['Active Cases'],y=sample_df['Name of State / UT'])

# %%
plt.figure(figsize=(40,15))
sample_df['Name of State / UT'].value_counts().plot.pie(autopct="%1.1f%%")
